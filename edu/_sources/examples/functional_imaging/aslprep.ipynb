# %% [markdown]
# # ASLprep
#
# **Author:** Steffen Bollmann
#
# **Citation:**
#
# __ASLPrep:__
# - Adebimpe, A., Bertolero, M., Dolui, S. et al. ASLPrep: a platform for processing of arterial spin labeled MRI and quantification of regional brain perfusion. Nat Methods 19, 683–686 (2022). [https://doi.org/10.1038/s41592-022-01458-7](https://doi.org/10.1038/s41592-022-01458-7)
#
# __Opensource Data from OpenNeuro:__
#
# - Alvaro Galiano and Reyes Garcia de Eulate and Marta Vidorreta and Miriam Recio and Mario Riverol and José L. Zubieta and Maria A. Fernandez-Seara PhD (2021). Resting State Perfusion in Healthy Aging. OpenNeuro Dataset ds000240.[doi: 10.18112/openneuro.ds000240.v2.0.0](https://openneuro.org/datasets/ds000240/versions/2.0.0)

# %% [markdown]
# ### Output CPU information:

# %%
# !cat /proc/cpuinfo | grep 'vendor' | uniq
# !cat /proc/cpuinfo | grep 'model name' | uniq
# Out:
# vendor_id	: AuthenticAMD
# model name	: AMD EPYC-Rome Processor

# %% [markdown]
# ## Run aslprep

# %%
# load fmriprep
import module
import os
await module.load('aslprep/0.7.2')
await module.list()
# Out:
# ['aslprep/0.7.2']

# %%
# Request a freesurfer license and store it in your homedirectory. This is just an exampe - please replace with your license id:
# !echo "Steffen.Bollmann@cai.uq.edu.au" > ~/.license
# !echo "21029" >> ~/.license
# !echo "*Cqyn12sqTCxo" >> ~/.license
# !echo "FSxgcvGkNR59Y" >> ~/.license

# %%
# download data using datalad
# !datalad install https://github.com/OpenNeuroDatasets/ds000240.git
# !cd ds000240 && datalad get sub-01
# Out:
# Cloning:   0%|                             | 0.00/2.00 [00:00<?, ? candidates/s]
# Enumerating: 0.00 Objects [00:00, ? Objects/s]
#
# Counting:   0%|                              | 0.00/1.20k [00:00<?, ? Objects/s]
#
# Compressing:   0%|                             | 0.00/883 [00:00<?, ? Objects/s]
#
# Receiving:   0%|                             | 0.00/2.39k [00:00<?, ? Objects/s]
#
# Resolving:   0%|                                | 0.00/256 [00:00<?, ? Deltas/s]
# [INFO   ] scanning for unlocked files (this may take some time)
# [INFO   ] Remote origin not usable by git-annex; setting annex-ignore
# [INFO   ] access to 1 dataset sibling s3-PRIVATE not auto-enabled, enable with:
# | 		datalad siblings -d "/home/jovyan/example-notebooks/books/functional_imaging/ds000240" enable -s s3-PRIVATE
# install(ok): /home/jovyan/example-notebooks/books/functional_imaging/ds000240 (dataset)
# Total:   0%|                                   | 0.00/18.0M [00:00<?, ? Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   0%|            | 0.00/9.52M [00:00<?, ? Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   0%|   | 33.4k/9.52M [00:00<02:10, 72.9k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   1%|   | 50.8k/9.52M [00:00<02:07, 74.4k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   1%|   | 62.6k/9.52M [00:00<02:22, 66.3k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   1%|   | 79.0k/9.52M [00:01<02:18, 68.2k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   1%|    | 114k/9.52M [00:01<02:40, 58.4k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   2%|    | 149k/9.52M [00:02<02:26, 64.0k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   2%|    | 183k/9.52M [00:02<02:08, 72.7k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   2%|    | 218k/9.52M [00:02<01:53, 81.8k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   2%|    | 236k/9.52M [00:03<01:50, 84.1k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   3%|    | 270k/9.52M [00:03<01:37, 94.6k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   3%|▏    | 305k/9.52M [00:03<01:22, 111k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   4%|▏    | 357k/9.52M [00:03<01:04, 142k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   4%|▏    | 392k/9.52M [00:04<00:59, 153k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   5%|▏    | 445k/9.52M [00:04<00:51, 176k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   5%|▎    | 497k/9.52M [00:04<00:42, 211k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   6%|▎    | 566k/9.52M [00:04<00:36, 247k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   6%|▎    | 601k/9.52M [00:04<00:35, 251k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   7%|▎    | 653k/9.52M [00:04<00:33, 261k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   8%|▍    | 740k/9.52M [00:05<00:28, 304k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:   9%|▍    | 828k/9.52M [00:05<00:23, 373k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  10%|▍    | 915k/9.52M [00:05<00:22, 391k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  11%|▍   | 1.02M/9.52M [00:05<00:20, 418k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  11%|▍   | 1.07M/9.52M [00:05<00:19, 430k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  12%|▍   | 1.14M/9.52M [00:05<00:17, 477k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  13%|▌   | 1.21M/9.52M [00:06<00:17, 463k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  14%|▌   | 1.37M/9.52M [00:06<00:14, 577k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  15%|▌   | 1.45M/9.52M [00:06<00:12, 635k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  16%|▋   | 1.54M/9.52M [00:06<00:12, 615k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  18%|▋   | 1.70M/9.52M [00:06<00:10, 751k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  20%|▊   | 1.87M/9.52M [00:06<00:09, 795k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  22%|▉   | 2.13M/9.52M [00:07<00:08, 886k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  25%|▉   | 2.38M/9.52M [00:07<00:07, 925k Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  28%|▊  | 2.62M/9.52M [00:07<00:06, 1.01M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  31%|▉  | 2.92M/9.52M [00:07<00:05, 1.10M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  34%|█  | 3.23M/9.52M [00:08<00:05, 1.12M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  37%|█  | 3.49M/9.52M [00:08<00:05, 1.17M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  38%|█▏ | 3.67M/9.52M [00:08<00:04, 1.26M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  40%|█▏ | 3.82M/9.52M [00:08<00:04, 1.32M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  43%|█▎ | 4.05M/9.52M [00:08<00:03, 1.44M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  45%|█▎ | 4.24M/9.52M [00:08<00:03, 1.54M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  47%|█▍ | 4.45M/9.52M [00:08<00:03, 1.59M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  49%|█▍ | 4.67M/9.52M [00:09<00:03, 1.56M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  51%|█▌ | 4.90M/9.52M [00:09<00:02, 1.73M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  56%|█▋ | 5.32M/9.52M [00:09<00:02, 1.87M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  59%|█▊ | 5.63M/9.52M [00:09<00:01, 1.96M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  62%|█▊ | 5.95M/9.52M [00:09<00:01, 1.97M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  65%|█▉ | 6.19M/9.52M [00:09<00:01, 2.06M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  68%|██ | 6.43M/9.52M [00:09<00:01, 2.14M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  70%|██ | 6.68M/9.52M [00:09<00:01, 2.22M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  73%|██▏| 6.97M/9.52M [00:10<00:01, 2.38M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  76%|██▎| 7.23M/9.52M [00:10<00:00, 2.37M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  80%|██▍| 7.60M/9.52M [00:10<00:00, 2.68M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  85%|██▌| 8.09M/9.52M [00:10<00:00, 2.58M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  89%|██▋| 8.43M/9.52M [00:10<00:00, 2.39M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  92%|██▊| 8.78M/9.52M [00:10<00:00, 2.62M Bytes/s]
# Get sub-01/a .. 1_T1w.nii.gz:  96%|██▉| 9.17M/9.52M [00:10<00:00, 2.81M Bytes/s]
# Total:  53%|██████████████▎            | 9.52M/18.0M [00:12<00:11, 748k Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:   0%|            | 0.00/8.48M [00:00<?, ? Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:   7%|▎   | 555k/8.48M [00:00<00:01, 5.54M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  20%|▌  | 1.67M/8.48M [00:00<00:01, 3.88M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  29%|▊  | 2.42M/8.48M [00:00<00:01, 4.53M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  36%|█  | 3.05M/8.48M [00:00<00:01, 3.93M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  42%|█▎ | 3.54M/8.48M [00:00<00:01, 3.93M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  47%|█▍ | 3.96M/8.48M [00:00<00:01, 4.01M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  54%|█▌ | 4.55M/8.48M [00:01<00:00, 4.22M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  59%|█▊ | 5.01M/8.48M [00:01<00:00, 4.30M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  66%|█▉ | 5.64M/8.48M [00:01<00:00, 4.47M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  72%|██▏| 6.13M/8.48M [00:01<00:00, 4.58M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  80%|██▍| 6.75M/8.48M [00:01<00:00, 4.75M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz:  94%|██▊| 7.96M/8.48M [00:01<00:00, 4.97M Bytes/s]
# Get sub-01/p .. 1_asl.nii.gz: 100%|██▉| 8.47M/8.48M [00:01<00:00, 4.98M Bytes/s]
# get(ok): sub-01/anat/sub-01_T1w.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-01/perf/sub-01_asl.nii.gz (file) [from s3-PUBLIC...]
# get(ok): sub-01 (directory)
# action summary:
#   get (ok: 3)

# %%
# %%bash
# # aslprep data/bids_root/ out/ participant -w work/
# aslprep ds000240 \
#    aslprep-output \
#    participant \
#    --participant-label 01 \
#    --fs-license-file ~/.license \
#    -w aslprep-work
# Out:
# bids-validator@1.14.5
# (node:14285) Warning: Closing directory handle on garbage collection
# (Use `node --trace-warnings ...` to show where the warning was created)
# This dataset appears to be BIDS compatible.
#         Summary:                  Available Tasks:        Available Modalities:
#         133 Files, 17.76MB                                MRI
#         63 - Subjects
#         1 - Session
#
#
# 	If you have any questions, please post on https://neurostars.org/tags/bids.
# 241015-23:33:33,303 nipype.workflow IMPORTANT:
# 	 Running ASLPrep version 0.7.2
#
#          License NOTICE ##################################################
#          ASLPrep 0.7.2
#          Copyright 2023 The PennLINC Team and the NiPreps Developers.
#
#          This product is primarily developed by the PennLINC team,
#          but it is also a part of the NiPreps community.
#
#          This product includes software developed by
#          the NiPreps Community (https://nipreps.org/).
#
#          Portions of this software were developed at the Department of
#          Psychology at Stanford University, Stanford, CA, US.
#
#          This software is also distributed as a Docker container image.
#          The bootstrapping file for the image ("Dockerfile") is licensed
#          under the MIT License.
#
#          This software may be distributed through an add-on package called
#          "Docker Wrapper" that is under the BSD 3-clause License.
#          #################################################################
# 241015-23:33:35,956 nipype.workflow IMPORTANT:
# 	 Building ASLPrep's workflow:
#            * BIDS dataset path: /home/jovyan/example-notebooks/books/functional_imaging/ds000240.
#            * Participant list: ['01'].
#            * Run identifier: 20241015-233301_3bb07981-a206-4abb-a9aa-fb634e8f410d.
#            * Output spaces: MNI152NLin2009cAsym:res-native.
#            * Pre-run FreeSurfer's SUBJECTS_DIR: /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer.
# 241015-23:33:36,843 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 241015-23:33:37,795 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 241015-23:33:37,992 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 241015-23:33:38,3 nipype.workflow INFO:
# 	 ANAT Stage 4: Preparing normalization workflow for ['MNI152NLin2009cAsym']
# 241015-23:33:38,21 nipype.workflow INFO:
# 	 ANAT Stage 5: Preparing surface reconstruction workflow
# 241015-23:33:38,65 nipype.workflow INFO:
# 	 ANAT Stage 6: Preparing mask refinement workflow
# 241015-23:33:38,70 nipype.workflow INFO:
# 	 ANAT No T2w images provided - skipping Stage 7
# 241015-23:33:38,71 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI surfaces for ['white', 'pial', 'midthickness', 'sphere_reg', 'sphere']
# 241015-23:33:38,109 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI metrics for ['thickness', 'sulc']
# 241015-23:33:38,125 nipype.workflow INFO:
# 	 ANAT Stage 8a: Creating cortical ribbon mask
# 241015-23:33:38,136 nipype.workflow INFO:
# 	 ANAT Stage 9: Creating fsLR registration sphere
# 241015-23:33:38,148 nipype.workflow INFO:
# 	 ANAT Stage 10: MSM-Sulc disabled
# 241015-23:33:38,577 nipype.workflow INFO:
# 	 Collected run data for /home/jovyan/example-notebooks/books/functional_imaging/ds000240/sub-01/perf/sub-01_asl.nii.gz:
# aslcontext: /home/jovyan/example-notebooks/books/functional_imaging/ds000240/sub-01/perf/sub-01_aslcontext.tsv
# m0scan: null
# sbref: null
#
# 241015-23:33:38,614 nipype.workflow INFO:
# 	 No single-band-reference found for sub-01_asl.nii.gz.
# 241015-23:33:38,829 nipype.workflow INFO:
# 	 Stage 1: Adding HMC aslref workflow
# 241015-23:33:38,845 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 241015-23:33:38,857 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration aslref workflow
# 241015-23:33:46,466 nipype.workflow INFO:
# 	 ASLPrep workflow graph with 414 nodes built successfully.
# 241015-23:34:14,129 nipype.workflow IMPORTANT:
# 	 ASLPrep started!
# 241015-23:34:18,459 nipype.interface WARNING:
# 	 Cannot determine world direction of phase encoding. Orientation: RAS; PE dir: None
# 241015-23:34:23,642 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 241015-23:34:23,646 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:23,907 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 241015-23:34:23,910 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 241015-23:34:24,16 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.processing_target" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/processing_target".
# 241015-23:34:24,18 nipype.workflow INFO:
# 	 [Node] Executing "processing_target" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,132 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 241015-23:34:24,134 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:34:24,354 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.ds_hmc_aslref_wf.raw_sources" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/ds_hmc_aslref_wf/raw_sources".
# 241015-23:34:24,358 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,364 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000742s.
# 241015-23:34:24,368 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.ds_hmc_wf.raw_sources" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/ds_hmc_wf/raw_sources".
# 241015-23:34:24,371 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,372 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000636s.
# 241015-23:34:24,375 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_native_wf.processing_target" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_native_wf/processing_target".
# 241015-23:34:24,378 nipype.workflow INFO:
# 	 [Node] Executing "processing_target" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,513 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.hmc_aslref_wf.val_asl" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/hmc_aslref_wf/val_asl".
# 241015-23:34:24,516 nipype.workflow INFO:
# 	 [Node] Executing "val_asl" <niworkflows.interfaces.header.ValidateImage>
# 241015-23:34:24,626 nipype.workflow INFO:
# 	 [Node] Finished "val_asl", elapsed time 0.103679s.
# 241015-23:34:24,638 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.ds_asl_std_wf.raw_sources" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/ds_asl_std_wf/raw_sources".
# 241015-23:34:24,641 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,643 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000873s.
# 241015-23:34:24,644 nipype.workflow INFO:
# 	 [Node] Finished "processing_target", elapsed time 0.620777s.
# 241015-23:34:24,658 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.parcellate_cbf_wf.atlas_name_grabber" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_name_grabber".
# 241015-23:34:24,661 nipype.workflow INFO:
# 	 [Node] Executing "atlas_name_grabber" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:24,662 nipype.workflow INFO:
# 	 [Node] Finished "atlas_name_grabber", elapsed time 0.000655s.
# 241015-23:34:25,9 nipype.workflow INFO:
# 	 [Node] Finished "processing_target", elapsed time 0.630156s.
# 241015-23:34:25,20 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 1.367654s.
# 241015-23:34:25,68 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_native_wf.validate_asl" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_native_wf/validate_asl".
# 241015-23:34:25,70 nipype.workflow INFO:
# 	 [Node] Executing "validate_asl" <niworkflows.interfaces.header.ValidateImage>
# 241015-23:34:25,185 nipype.workflow INFO:
# 	 [Node] Finished "validate_asl", elapsed time 0.109683s.
# 241015-23:34:25,668 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 1.751608s.
# 241015-23:34:27,873 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber0".
# 241015-23:34:27,876 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber1".
# 241015-23:34:27,878 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber2".
# 241015-23:34:27,878 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber0" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,879 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber3" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber3".
# 241015-23:34:27,880 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber1" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,880 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber4" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber4".
# 241015-23:34:27,882 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber2" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,882 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber5" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber5".
# 241015-23:34:27,883 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber3" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,883 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber6" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber6".
# 241015-23:34:27,885 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber4" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,886 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber5" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,886 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber6" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,889 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber3", elapsed time 0.004739s.
# 241015-23:34:27,891 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber1", elapsed time 0.004406s.
# 241015-23:34:27,893 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber7" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber7".
# 241015-23:34:27,894 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber6", elapsed time 0.006154s.
# 241015-23:34:27,894 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber2", elapsed time 0.006392s.
# 241015-23:34:27,896 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber8" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber8".
# 241015-23:34:27,896 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber7" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,897 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber9" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber9".
# 241015-23:34:27,898 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber8" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,900 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber9" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,903 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber4", elapsed time 0.011844s.
# 241015-23:34:27,903 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber5", elapsed time 0.009827s.
# 241015-23:34:27,904 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber8", elapsed time 0.004553s.
# 241015-23:34:27,904 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber7", elapsed time 0.006769s.
# 241015-23:34:27,904 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber9", elapsed time 0.003245s.
# 241015-23:34:27,904 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber10" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber10".
# 241015-23:34:27,904 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber0", elapsed time 0.025012s.
# 241015-23:34:27,907 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber11" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber11".
# 241015-23:34:27,907 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber12" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber12".
# 241015-23:34:27,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber13" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber13".
# 241015-23:34:27,909 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber11" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,909 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber12" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,910 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber13" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,910 nipype.workflow INFO:
# 	 [Node] Executing "_atlas_file_grabber10" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:27,911 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber11", elapsed time 0.001751s.
# 241015-23:34:27,912 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber12", elapsed time 0.00191s.
# 241015-23:34:27,913 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber13", elapsed time 0.001958s.
# 241015-23:34:27,914 nipype.workflow INFO:
# 	 [Node] Finished "_atlas_file_grabber10", elapsed time 0.002364s.
# 241015-23:34:28,832 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.bidssrc" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/bidssrc".
# 241015-23:34:28,835 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <aslprep.interfaces.bids.BIDSDataGrabber>
# 241015-23:34:28,840 nipype.interface INFO:
# 	 No "t2w" images found for sub-01
# 241015-23:34:28,840 nipype.interface INFO:
# 	 No "flair" images found for sub-01
# 241015-23:34:28,840 nipype.interface INFO:
# 	 No "fmap" images found for sub-01
# 241015-23:34:28,840 nipype.interface INFO:
# 	 No "sbref" images found for sub-01
# 241015-23:34:28,841 nipype.interface INFO:
# 	 No "roi" images found for sub-01
# 241015-23:34:28,842 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.001041s.
# 241015-23:34:29,579 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.hmc_aslref_wf.select_highest_contrast_volumes" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/hmc_aslref_wf/select_highest_contrast_volumes".
# 241015-23:34:29,589 nipype.workflow INFO:
# 	 [Node] Executing "select_highest_contrast_volumes" <aslprep.interfaces.reference.SelectHighestContrastVolumes>
# 241015-23:34:29,657 nipype.interface INFO:
# 	 Selecting m0scan as highest-contrast volume type for reference volume generation.
# 241015-23:34:29,851 nipype.workflow INFO:
# 	 [Node] Finished "select_highest_contrast_volumes", elapsed time 0.261419s.
# 241015-23:34:30,165 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 241015-23:34:30,374 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber0".
# 241015-23:34:30,375 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber0" - collecting precomputed outputs
# 241015-23:34:30,376 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber0" found cached.
# 241015-23:34:30,377 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber1".
# 241015-23:34:30,378 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber1" - collecting precomputed outputs
# 241015-23:34:30,378 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber1" found cached.
# 241015-23:34:30,380 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber2".
# 241015-23:34:30,381 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber2" - collecting precomputed outputs
# 241015-23:34:30,381 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber2" found cached.
# 241015-23:34:30,382 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber3" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber3".
# 241015-23:34:30,383 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber3" - collecting precomputed outputs
# 241015-23:34:30,383 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber3" found cached.
# 241015-23:34:30,385 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber4" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber4".
# 241015-23:34:30,386 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber4" - collecting precomputed outputs
# 241015-23:34:30,386 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber4" found cached.
# 241015-23:34:30,387 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber5" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber5".
# 241015-23:34:30,388 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber5" - collecting precomputed outputs
# 241015-23:34:30,388 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber5" found cached.
# 241015-23:34:30,389 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber6" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber6".
# 241015-23:34:30,390 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber6" - collecting precomputed outputs
# 241015-23:34:30,390 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber6" found cached.
# 241015-23:34:30,392 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber7" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber7".
# 241015-23:34:30,393 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber7" - collecting precomputed outputs
# 241015-23:34:30,393 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber7" found cached.
# 241015-23:34:30,394 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber8" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber8".
# 241015-23:34:30,395 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber8" - collecting precomputed outputs
# 241015-23:34:30,395 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber8" found cached.
# 241015-23:34:30,396 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber9" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber9".
# 241015-23:34:30,397 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber9" - collecting precomputed outputs
# 241015-23:34:30,397 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber9" found cached.
# 241015-23:34:30,398 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber10" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber10".
# 241015-23:34:30,399 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber10" - collecting precomputed outputs
# 241015-23:34:30,400 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber10" found cached.
# 241015-23:34:30,401 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber11" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber11".
# 241015-23:34:30,402 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber11" - collecting precomputed outputs
# 241015-23:34:30,402 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber11" found cached.
# 241015-23:34:30,403 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber12" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber12".
# 241015-23:34:30,404 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber12" - collecting precomputed outputs
# 241015-23:34:30,404 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber12" found cached.
# 241015-23:34:30,406 nipype.workflow INFO:
# 	 [Node] Setting-up "_atlas_file_grabber13" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/atlas_file_grabber/mapflow/_atlas_file_grabber13".
# 241015-23:34:30,407 nipype.workflow INFO:
# 	 [Node] Cached "_atlas_file_grabber13" - collecting precomputed outputs
# 241015-23:34:30,407 nipype.workflow INFO:
# 	 [Node] "_atlas_file_grabber13" found cached.
# 241015-23:34:30,602 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.reduce_asl_file" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/reduce_asl_file".
# 241015-23:34:30,608 nipype.workflow INFO:
# 	 [Node] Executing "reduce_asl_file" <aslprep.interfaces.utility.ReduceASLFiles>
# 241015-23:34:31,756 nipype.workflow INFO:
# 	 [Node] Finished "reduce_asl_file", elapsed time 1.146737s.
# 241015-23:34:31,811 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_native_wf.reduce_asl_file" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_native_wf/reduce_asl_file".
# 241015-23:34:31,835 nipype.workflow INFO:
# 	 [Node] Executing "reduce_asl_file" <aslprep.interfaces.utility.ReduceASLFiles>
# 241015-23:34:31,996 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.hmc_aslref_wf.gen_avg" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/hmc_aslref_wf/gen_avg".
# 241015-23:34:32,671 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.bids_info" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/bids_info".
# 241015-23:34:32,967 nipype.workflow INFO:
# 	 [Node] Finished "reduce_asl_file", elapsed time 1.130671s.
# 241015-23:34:33,985 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities0".
# 241015-23:34:33,987 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities1".
# 241015-23:34:33,987 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities2".
# 241015-23:34:33,988 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities0" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,989 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities3" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities3".
# 241015-23:34:33,990 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities0", elapsed time 0.001176s.
# 241015-23:34:33,990 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities1" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,990 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities4" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities4".
# 241015-23:34:33,991 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities2" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,992 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities5" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities5".
# 241015-23:34:33,993 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities6" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities6".
# 241015-23:34:33,993 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities1", elapsed time 0.001407s.
# 241015-23:34:33,993 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities3" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,994 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities4" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,994 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities2", elapsed time 0.001834s.
# 241015-23:34:33,995 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities5" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,995 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities7" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities7".
# 241015-23:34:33,996 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities6" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,996 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities9" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities9".
# 241015-23:34:33,996 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities3", elapsed time 0.001857s.
# 241015-23:34:33,996 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities4", elapsed time 0.001559s.
# 241015-23:34:33,997 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities8" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities8".
# 241015-23:34:33,997 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities5", elapsed time 0.001334s.
# 241015-23:34:33,998 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities7" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:33,998 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities9" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,0 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities8" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,0 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities9", elapsed time 0.001067s.
# 241015-23:34:34,1 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities7", elapsed time 0.001594s.
# 241015-23:34:34,1 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities10" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities10".
# 241015-23:34:34,3 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities6", elapsed time 0.001567s.
# 241015-23:34:34,4 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities13" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities13".
# 241015-23:34:34,4 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities12" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities12".
# 241015-23:34:34,4 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities11" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities11".
# 241015-23:34:34,5 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities10" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,6 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities8", elapsed time 0.001389s.
# 241015-23:34:34,6 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities13" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,7 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities11" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,7 nipype.workflow INFO:
# 	 [Node] Executing "_get_atlas_entities12" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:34,8 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities13", elapsed time 0.001059s.
# 241015-23:34:34,9 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities11", elapsed time 0.001382s.
# 241015-23:34:34,10 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities12", elapsed time 0.001622s.
# 241015-23:34:34,13 nipype.workflow INFO:
# 	 [Node] Finished "_get_atlas_entities10", elapsed time 0.001582s.
# 241015-23:34:35,964 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 241015-23:34:36,35 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities0".
# 241015-23:34:36,36 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities0" - collecting precomputed outputs
# 241015-23:34:36,36 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities0" found cached.
# 241015-23:34:36,38 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities1".
# 241015-23:34:36,39 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities1" - collecting precomputed outputs
# 241015-23:34:36,39 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities1" found cached.
# 241015-23:34:36,41 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities2".
# 241015-23:34:36,42 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities2" - collecting precomputed outputs
# 241015-23:34:36,42 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities2" found cached.
# 241015-23:34:36,44 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities3" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities3".
# 241015-23:34:36,45 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities3" - collecting precomputed outputs
# 241015-23:34:36,45 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities3" found cached.
# 241015-23:34:36,47 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities4" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities4".
# 241015-23:34:36,48 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities4" - collecting precomputed outputs
# 241015-23:34:36,48 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities4" found cached.
# 241015-23:34:36,49 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities5" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities5".
# 241015-23:34:36,50 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities5" - collecting precomputed outputs
# 241015-23:34:36,50 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities5" found cached.
# 241015-23:34:36,52 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities6" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities6".
# 241015-23:34:36,53 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities6" - collecting precomputed outputs
# 241015-23:34:36,53 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities6" found cached.
# 241015-23:34:36,55 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities7" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities7".
# 241015-23:34:36,56 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities7" - collecting precomputed outputs
# 241015-23:34:36,57 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities7" found cached.
# 241015-23:34:36,59 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities8" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities8".
# 241015-23:34:36,60 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities8" - collecting precomputed outputs
# 241015-23:34:36,60 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities8" found cached.
# 241015-23:34:36,62 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities9" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities9".
# 241015-23:34:36,64 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities9" - collecting precomputed outputs
# 241015-23:34:36,64 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities9" found cached.
# 241015-23:34:36,65 nipype.workflow INFO:
# 	 [Node] Executing "bids_info" <niworkflows.interfaces.bids.BIDSInfo>
# 241015-23:34:36,66 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities10" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities10".
# 241015-23:34:36,67 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities10" - collecting precomputed outputs
# 241015-23:34:36,67 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities10" found cached.
# 241015-23:34:36,69 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities11" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities11".
# 241015-23:34:36,70 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities11" - collecting precomputed outputs
# 241015-23:34:36,70 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities11" found cached.
# 241015-23:34:36,70 nipype.workflow INFO:
# 	 [Node] Finished "bids_info", elapsed time 0.004438s.
# 241015-23:34:36,72 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities12" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities12".
# 241015-23:34:36,73 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities12" - collecting precomputed outputs
# 241015-23:34:36,73 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities12" found cached.
# 241015-23:34:36,75 nipype.workflow INFO:
# 	 [Node] Setting-up "_get_atlas_entities13" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/parcellate_cbf_wf/get_atlas_entities/mapflow/_get_atlas_entities13".
# 241015-23:34:36,76 nipype.workflow INFO:
# 	 [Node] Cached "_get_atlas_entities13" - collecting precomputed outputs
# 241015-23:34:36,76 nipype.workflow INFO:
# 	 [Node] "_get_atlas_entities13" found cached.
# 241015-23:34:36,653 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.688146s.
# 241015-23:34:37,293 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 12.793348s.
# 241015-23:34:37,736 nipype.workflow INFO:
# 	 [Node] Executing "gen_avg" <niworkflows.interfaces.images.RobustAverage>
# 241015-23:34:37,992 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.mrg_tmpl" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/mrg_tmpl".
# 241015-23:34:37,998 nipype.workflow INFO:
# 	 [Node] Executing "mrg_tmpl" <nipype.interfaces.utility.base.Merge>
# 241015-23:34:37,999 nipype.workflow INFO:
# 	 [Node] Finished "mrg_tmpl", elapsed time 0.000406s.
# 241015-23:34:38,257 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.fs_isrunning" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/fs_isrunning".
# 241015-23:34:38,263 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 241015-23:34:38,264 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.ds_ribbon_mask_wf.raw_sources" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/ds_ribbon_mask_wf/raw_sources".
# 241015-23:34:38,273 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 241015-23:34:38,276 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 241015-23:34:38,494 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.493961:++ 3dvolreg: AFNI version=AFNI_24.1.08 (May  2 2024) [64-bit]
# 241015-23:34:38,494 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.493961:++ Authored by: RW Cox
# 241015-23:34:38,499 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.499782:** AFNI converts NIFTI_datatype=4 (INT16) in file /home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/hmc_aslref_wf/gen_avg/sub-01_asl_contrast_sliced.nii.gz to FLOAT32
# 241015-23:34:38,499 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.499782:     Warnings of this type will be muted for this session.
# 241015-23:34:38,500 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.499782:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 241015-23:34:38,514 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:38.514547:++ Coarse del was 10, replaced with 2
# 241015-23:34:38,796 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:38,798 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000885s.
# 241015-23:34:38,799 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:38,801 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000814s.
# 241015-23:34:40,468 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S1056Parcels/space-MNI152NLin6Asym_atlas-4S1056Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:40,732 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.asl_preproc_asl.asl_fit_wf.asl_hmc_wf.split_by_volume_type" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/asl_preproc_asl/asl_fit_wf/asl_hmc_wf/split_by_volume_type".
# 241015-23:34:40,737 nipype.workflow INFO:
# 	 [Node] Executing "split_by_volume_type" <aslprep.interfaces.utility.SplitByVolumeType>
# 241015-23:34:41,146 nipype.workflow INFO:
# 	 [Node] Executing "fs_isrunning" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:34:41,149 nipype.workflow INFO:
# 	 [Node] Finished "fs_isrunning", elapsed time 0.001225s.
# 241015-23:34:41,947 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S156Parcels/space-MNI152NLin6Asym_atlas-4S156Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:42,403 nipype.workflow INFO:
# 	 [Node] Finished "split_by_volume_type", elapsed time 1.663437s.
# 241015-23:34:43,43 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S256Parcels/space-MNI152NLin6Asym_atlas-4S256Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:44,73 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S356Parcels/space-MNI152NLin6Asym_atlas-4S356Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:44,726 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:44.726188:++ Max displacement in automask = 0.96 (mm) at sub-brick 3
# 241015-23:34:44,726 nipype.interface INFO:
# 	 stderr 2024-10-15T23:34:44.726188:++ Max delta displ  in automask = 0.93 (mm) at sub-brick 3
# 241015-23:34:45,106 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S456Parcels/space-MNI152NLin6Asym_atlas-4S456Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:45,362 nipype.workflow INFO:
# 	 [Node] Finished "gen_avg", elapsed time 7.6249590000000005s.
# 241015-23:34:46,275 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S556Parcels/space-MNI152NLin6Asym_atlas-4S556Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:48,55 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S656Parcels/space-MNI152NLin6Asym_atlas-4S656Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:49,99 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S756Parcels/space-MNI152NLin6Asym_atlas-4S756Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:50,112 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S856Parcels/space-MNI152NLin6Asym_atlas-4S856Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:51,156 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-4S956Parcels/space-MNI152NLin6Asym_atlas-4S956Parcels_res-01_dseg.nii.gz dtype from uint32 to int16
# 241015-23:34:52,237 nipype.interface WARNING:
# 	 Changing /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/atlases/atlas-Glasser/space-MNI152NLin6Asym_atlas-Glasser_res-01_dseg.nii.gz dtype from float32 to int16
# 241015-23:34:53,427 nipype.interface WARNING:
# ...
# 241015-23:49:36,28 nipype.workflow INFO:
# 	 [Node] Executing "20_add_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:49:38,471 nipype.workflow INFO:
# 	 [Node] Finished "20_add_7_2", elapsed time 1.861071s.
# 241015-23:49:40,73 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.21_md_7_2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/21_md_7_2".
# 241015-23:49:40,79 nipype.workflow INFO:
# 	 [Node] Executing "21_md_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:49:42,739 nipype.workflow INFO:
# 	 [Node] Finished "21_md_7_2", elapsed time 2.6590160000000003s.
# 241015-23:49:44,73 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.22_me_7_2" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/22_me_7_2".
# 241015-23:49:44,78 nipype.workflow INFO:
# 	 [Node] Executing "22_me_7_2" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:49:48,261 nipype.workflow INFO:
# 	 [Node] Finished "22_me_7_2", elapsed time 4.181631s.
# 241015-23:49:49,947 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.23_depad_mask" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/23_depad_mask".
# 241015-23:49:49,954 nipype.workflow INFO:
# 	 [Node] Executing "23_depad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:49:51,187 nipype.workflow INFO:
# 	 [Node] Finished "23_depad_mask", elapsed time 1.231229s.
# 241015-23:49:52,19 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.msk_conform" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/msk_conform".
# 241015-23:49:52,26 nipype.workflow INFO:
# 	 [Node] Executing "msk_conform" <nipype.interfaces.utility.wrappers.Function>
# 241015-23:49:52,368 nipype.workflow INFO:
# 	 [Node] Finished "msk_conform", elapsed time 0.341015s.
# 241015-23:50:02,243 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_mask0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/apply_mask/mapflow/_apply_mask0".
# 241015-23:50:02,245 nipype.workflow INFO:
# 	 [Node] Executing "_apply_mask0" <niworkflows.interfaces.nibabel.ApplyMask>
# 241015-23:50:03,277 nipype.workflow INFO:
# 	 [Node] Finished "_apply_mask0", elapsed time 1.030496s.
# 241015-23:50:06,856 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.register_template_wf.trunc_mov" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/register_template_wf/_template_MNI152NLin2009cAsym/trunc_mov".
# 241015-23:50:06,857 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.ds_std_volumes_wf.gen_ref" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/ds_std_volumes_wf/_in_tuple_MNI152NLin2009cAsym.resnative/gen_ref".
# 241015-23:50:06,862 nipype.workflow INFO:
# 	 [Node] Executing "trunc_mov" <nipype.interfaces.ants.utils.ImageMath>
# 241015-23:50:08,509 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.surface_recon_wf.skull_strip_extern" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/skull_strip_extern".
# 241015-23:50:09,295 nipype.workflow INFO:
# 	 [Node] Executing "gen_ref" <niworkflows.interfaces.nibabel.GenerateSamplingReference>
# 241015-23:50:11,156 nipype.workflow INFO:
# 	 [Node] Executing "skull_strip_extern" <niworkflows.interfaces.freesurfer.FSInjectBrainExtracted>
# 241015-23:50:13,427 nipype.workflow INFO:
# 	 [Node] Finished "trunc_mov", elapsed time 6.563622s.
# 241015-23:50:13,620 nipype.workflow INFO:
# 	 [Node] Finished "gen_ref", elapsed time 4.323494s.
# 241015-23:50:15,277 nipype.workflow INFO:
# 	 [Node] Finished "skull_strip_extern", elapsed time 4.119662s.
# 241015-23:50:20,870 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.surface_recon_wf.autorecon_resume_wf.gcareg" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/gcareg".
# 241015-23:50:20,874 nipype.workflow INFO:
# 	 [Node] Executing "gcareg" <smriprep.interfaces.freesurfer.ReconAll>
# 241015-23:50:20,876 nipype.interface INFO:
# 	 resume recon-all : recon-all -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -gcareg
# 241015-23:50:20,877 nipype.interface INFO:
# 	 resume recon-all : recon-all -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -gcareg
# 241015-23:54:44,373 nipype.workflow INFO:
# 	 [Node] Finished "gcareg", elapsed time 263.497329s.
# 241015-23:54:45,45 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.surface_recon_wf.autorecon_resume_wf.autorecon2_vol" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon2_vol".
# 241015-23:54:45,54 nipype.workflow INFO:
# 	 [Node] Executing "autorecon2_vol" <smriprep.interfaces.freesurfer.ReconAll>
# 241015-23:54:45,57 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon2-volonly -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -nogcareg
# 241015-23:54:45,60 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon2-volonly -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -nogcareg
# 241016-01:55:38,518 nipype.workflow INFO:
# 	 [Node] Finished "autorecon2_vol", elapsed time 7253.461031s.
# 241016-01:55:41,204 nipype.workflow INFO:
# 	 [Node] Setting-up "_autorecon_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon_surfs/mapflow/_autorecon_surfs0".
# 241016-01:55:41,204 nipype.workflow INFO:
# 	 [Node] Setting-up "_autorecon_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon_surfs/mapflow/_autorecon_surfs1".
# 241016-01:55:41,216 nipype.workflow INFO:
# 	 [Node] Executing "_autorecon_surfs0" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-01:55:41,218 nipype.workflow INFO:
# 	 [Node] Executing "_autorecon_surfs1" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-01:55:41,223 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi rh -noparcstats -noparcstats2 -noparcstats3 -nohyporelabel -nobalabels -rh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer
# 241016-01:55:41,224 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi rh -noparcstats -noparcstats2 -noparcstats3 -nohyporelabel -nobalabels -rh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer
# 241016-01:55:41,222 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi lh -noparcstats -noparcstats2 -noparcstats3 -nohyporelabel -nobalabels -lh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer
# 241016-01:55:41,230 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi lh -noparcstats -noparcstats2 -noparcstats3 -nohyporelabel -nobalabels -lh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer
# 241016-02:33:50,646 nipype.workflow INFO:
# 	 [Node] Finished "_autorecon_surfs0", elapsed time 2289.426188s.
# 241016-02:35:29,761 nipype.workflow INFO:
# 	 [Node] Finished "_autorecon_surfs1", elapsed time 2388.538778s.
# 241016-02:35:31,748 nipype.workflow INFO:
# 	 [Node] Setting-up "_autorecon_surfs0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon_surfs/mapflow/_autorecon_surfs0".
# 241016-02:35:31,754 nipype.workflow INFO:
# 	 [Node] Executing "_autorecon_surfs0" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:35:31,758 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:35:31,759 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:35:32,310 nipype.workflow INFO:
# 	 [Node] Finished "_autorecon_surfs0", elapsed time 0.553482s.
# 241016-02:35:32,318 nipype.workflow INFO:
# 	 [Node] Setting-up "_autorecon_surfs1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon_surfs/mapflow/_autorecon_surfs1".
# 241016-02:35:32,322 nipype.workflow INFO:
# 	 [Node] Executing "_autorecon_surfs1" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:35:32,324 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:35:32,325 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:35:32,524 nipype.workflow INFO:
# 	 [Node] Finished "_autorecon_surfs1", elapsed time 0.201104s.
# 241016-02:35:35,654 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.surface_recon_wf.autorecon_resume_wf.cortribbon" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/cortribbon".
# 241016-02:35:35,660 nipype.workflow INFO:
# 	 [Node] Executing "cortribbon" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:35:35,661 nipype.interface INFO:
# 	 resume recon-all : recon-all -parallel -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -cortribbon
# 241016-02:35:35,662 nipype.interface INFO:
# 	 resume recon-all : recon-all -parallel -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -cortribbon
# 241016-02:43:04,298 nipype.workflow INFO:
# 	 [Node] Finished "cortribbon", elapsed time 448.636713s.
# 241016-02:43:07,861 nipype.workflow INFO:
# 	 [Node] Setting-up "_parcstats0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/parcstats/mapflow/_parcstats0".
# 241016-02:43:07,863 nipype.workflow INFO:
# 	 [Node] Setting-up "_parcstats1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/parcstats/mapflow/_parcstats1".
# 241016-02:43:07,873 nipype.workflow INFO:
# 	 [Node] Executing "_parcstats0" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:43:07,874 nipype.workflow INFO:
# 	 [Node] Executing "_parcstats1" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:43:07,879 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi lh -nohyporelabel -lh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -notessellate -nosmooth1 -noinflate1 -noqsphere -nofix -nowhite -nosmooth2 -noinflate2 -nocurvHK -nocurvstats -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -nocortparc2 -nocortparc3 -nopctsurfcon
# 241016-02:43:07,880 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi lh -nohyporelabel -lh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -notessellate -nosmooth1 -noinflate1 -noqsphere -nofix -nowhite -nosmooth2 -noinflate2 -nocurvHK -nocurvstats -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -nocortparc2 -nocortparc3 -nopctsurfcon
# 241016-02:43:07,879 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi rh -nohyporelabel -rh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -notessellate -nosmooth1 -noinflate1 -noqsphere -nofix -nowhite -nosmooth2 -noinflate2 -nocurvHK -nocurvstats -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -nocortparc2 -nocortparc3 -nopctsurfcon
# 241016-02:43:07,886 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon-hemi rh -nohyporelabel -rh-only -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -notessellate -nosmooth1 -noinflate1 -noqsphere -nofix -nowhite -nosmooth2 -noinflate2 -nocurvHK -nocurvstats -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -nocortparc2 -nocortparc3 -nopctsurfcon
# 241016-02:48:29,720 nipype.workflow INFO:
# 	 [Node] Finished "_parcstats0", elapsed time 321.84365s.
# 241016-02:48:31,471 nipype.workflow INFO:
# 	 [Node] Finished "_parcstats1", elapsed time 323.593271s.
# 241016-02:48:32,59 nipype.workflow INFO:
# 	 [Node] Setting-up "_parcstats0" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/parcstats/mapflow/_parcstats0".
# 241016-02:48:32,65 nipype.workflow INFO:
# 	 [Node] Executing "_parcstats0" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:48:32,70 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:48:32,71 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:48:32,825 nipype.workflow INFO:
# 	 [Node] Finished "_parcstats0", elapsed time 0.756917s.
# 241016-02:48:32,834 nipype.workflow INFO:
# 	 [Node] Setting-up "_parcstats1" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/parcstats/mapflow/_parcstats1".
# 241016-02:48:32,838 nipype.workflow INFO:
# 	 [Node] Executing "_parcstats1" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:48:32,840 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:48:32,841 nipype.interface INFO:
# 	 recon-all complete : Not running
# 241016-02:48:33,183 nipype.workflow INFO:
# 	 [Node] Finished "_parcstats1", elapsed time 0.343395s.
# 241016-02:48:34,42 nipype.workflow INFO:
# 	 [Node] Setting-up "aslprep_0_7_wf.sub_01_wf.anat_fit_wf.surface_recon_wf.autorecon_resume_wf.autorecon3" in "/home/jovyan/example-notebooks/books/functional_imaging/aslprep-work/aslprep_0_7_wf/sub_01_wf/anat_fit_wf/surface_recon_wf/autorecon_resume_wf/autorecon3".
# 241016-02:48:34,57 nipype.workflow INFO:
# 	 [Node] Executing "autorecon3" <smriprep.interfaces.freesurfer.ReconAll>
# 241016-02:48:34,62 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon3 -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -noparcstats -nocortparc2 -noparcstats2 -nocortparc3 -noparcstats3 -nopctsurfcon -nocortribbon -nobalabels
# 241016-02:48:34,63 nipype.interface INFO:
# 	 resume recon-all : recon-all -autorecon3 -openmp 8 -subjid sub-01 -sd /home/jovyan/example-notebooks/books/functional_imaging/aslprep-output/sourcedata/freesurfer -nosphere -nosurfreg -nojacobian_white -noavgcurv -nocortparc -nopial -noparcstats -nocortparc2 -noparcstats2 -nocortparc3 -noparcstats3 -nopctsurfcon -nocortribbon -nobalabels

# %% [markdown]
# ## aslprep Results

# %% [markdown]
# The full result report is in aslprep-output/sub-01.html and you can open this webpage in Jupyterlab or in the browser. Here a few items from the report as an example and for a quick checking:

# %% [markdown]
# ### Brain mask and brain tissue segmentation of the T1w
# This panel shows the template T1-weighted image (if several T1w images were found), with contours delineating the detected brain mask and brain tissue segmentations.

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_dseg.svg')

# %% [markdown]
# ### Spatial normalization of the anatomical T1w reference
#
# Results of nonlinear alignment of the T1w reference one or more template space(s)

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_space-MNI152NLin2009cAsym_T1w.svg')

# %% [markdown]
# ### Surface reconstruction
# Surfaces (white and pial) reconstructed with FreeSurfer (recon-all) overlaid on the participant's T1w template.

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_desc-reconall_T1w.svg')

# %% [markdown]
# ## Alignment of functional and anatomical MRI data (volume based)
# mri_coreg (FreeSurfer) was used to generate transformations from EPI space to T1 Space - bbregister refinement rejected. Note that Nearest Neighbor interpolation is used in the reportlets in order to highlight potential spin-history and other artifacts, whereas final images are resampled using Lanczos interpolation.

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_desc-coreg_asl.svg')

# %% [markdown]
# ### ASL Summary
# Summary statistics are plotted, which may reveal trends or artifacts in the ASL data. DVARS and FD show the standardized DVARS and framewise-displacement measures for each time point. A carpet plot shows the time series for all voxels within the brain mask. Voxels are grouped into cortical (blue), and subcortical (orange) gray matter, cerebellum (green) and white matter and CSF (red), indicated by the color map on the left-hand side.

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_desc-carpetplot_asl.svg')

# %% [markdown]
# ### CBF
# The maps plot cerebral blood flow (CBF) for basic CBF. The unit is mL/100 g/min.

# %%
from IPython.core.display import SVG
SVG(filename='aslprep-output/sub-01/figures/sub-01_desc-cbf_cbf.svg')
